# %% [markdown]
# # Join traffic with pollution data

# %%
import pandas as pd

# %%
traffic = pd.read_csv("database\\traffic_date_value.csv")
pollution = pd.read_csv("database\\pollution_date_value.csv")

# %%
df_final = traffic.merge(pollution, left_on='FECHA_HORA', right_on='FECHA_HORA', how='left')

# %%
df_final
# Out:
#                  FECHA_HORA  IDELEM  INTENSIDAD  OCUPACION     CARGA  \
# 0       2017-01-01 00:00:00    3910  129.000000   1.000000  3.750000
# 1       2017-01-01 00:00:00    3911  151.000000   0.666667  3.666667
# 2       2017-01-01 00:00:00    3913  106.750000   0.000000  3.000000
# 3       2017-01-01 00:00:00    3914  145.500000   0.250000  3.750000
# 4       2017-01-01 00:00:00    3915  118.250000   0.250000  2.750000
# ...                     ...     ...         ...        ...       ...
# 477808  2024-12-31 23:00:00    3913   57.333333   0.000000  1.333333
# 477809  2024-12-31 23:00:00    3914   56.500000   0.000000  1.250000
# 477810  2024-12-31 23:00:00    3915   43.000000   0.000000  0.666667
# 477811  2024-12-31 23:00:00    3917   50.000000   0.000000  1.000000
# 477812  2024-12-31 23:00:00    5547   70.750000   0.000000  0.500000
#
#         MAGNITUD  TECNICA  CODIGO_ESTACION    NOMBRE_ESTACION  COD_MAGNITUD  \
# 0            8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 1            8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 2            8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 3            8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 4            8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# ...          ...      ...              ...                ...           ...
# 477808       8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 477809       8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 477810       8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 477811       8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
# 477812       8.0      8.0       28079011.0  Av. Ramón y Cajal           8.0
#
#              NOMBRE_MAGNITUD ABREVIATURA UNIDAD  COD_TECNICA  \
# 0       Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 1       Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 2       Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 3       Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 4       Dióxido de Nitrógeno         NO2  µg/m3          8.0
# ...                      ...         ...    ...          ...
# 477808  Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 477809  Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 477810  Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 477811  Dióxido de Nitrógeno         NO2  µg/m3          8.0
# 477812  Dióxido de Nitrógeno         NO2  µg/m3          8.0
#
#              TECNICA_MEDIDA  VALOR_CONTAMINACION
# 0       Quimioluminiscencia                 40.0
# 1       Quimioluminiscencia                 40.0
# 2       Quimioluminiscencia                 40.0
# 3       Quimioluminiscencia                 40.0
# 4       Quimioluminiscencia                 40.0
# ...                     ...                  ...
# 477808  Quimioluminiscencia                 62.0
# 477809  Quimioluminiscencia                 62.0
# 477810  Quimioluminiscencia                 62.0
# 477811  Quimioluminiscencia                 62.0
# 477812  Quimioluminiscencia                 62.0
#
# [477813 rows x 16 columns]

# %%
df_final = df_final.drop(columns=['MAGNITUD', 'TECNICA', 'CODIGO_ESTACION', 'NOMBRE_ESTACION', 'COD_MAGNITUD', 
                 'NOMBRE_MAGNITUD', 'ABREVIATURA', 'UNIDAD', 'COD_TECNICA',	'TECNICA_MEDIDA'])

# %%
df_final
# Out:
#                  FECHA_HORA  IDELEM  INTENSIDAD  OCUPACION     CARGA  \
# 0       2017-01-01 00:00:00    3910  129.000000   1.000000  3.750000
# 1       2017-01-01 00:00:00    3911  151.000000   0.666667  3.666667
# 2       2017-01-01 00:00:00    3913  106.750000   0.000000  3.000000
# 3       2017-01-01 00:00:00    3914  145.500000   0.250000  3.750000
# 4       2017-01-01 00:00:00    3915  118.250000   0.250000  2.750000
# ...                     ...     ...         ...        ...       ...
# 477808  2024-12-31 23:00:00    3913   57.333333   0.000000  1.333333
# 477809  2024-12-31 23:00:00    3914   56.500000   0.000000  1.250000
# 477810  2024-12-31 23:00:00    3915   43.000000   0.000000  0.666667
# 477811  2024-12-31 23:00:00    3917   50.000000   0.000000  1.000000
# 477812  2024-12-31 23:00:00    5547   70.750000   0.000000  0.500000
#
#         VALOR_CONTAMINACION
# 0                      40.0
# 1                      40.0
# 2                      40.0
# 3                      40.0
# 4                      40.0
# ...                     ...
# 477808                 62.0
# 477809                 62.0
# 477810                 62.0
# 477811                 62.0
# 477812                 62.0
#
# [477813 rows x 6 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from sklearn.metrics import mean_squared_error
